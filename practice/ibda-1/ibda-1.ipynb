# %%
import weather_generators as wg
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
t = wg.generate_temperature(-10, 15)
plt.plot(t)

# %%
plt.figure(figsize=(30,5))
h = wg.generate_humidity(t)
plt.plot(h, 'o')

# %%
plt.plot(wg.generate_lighting())

# %%
plt.plot(wg.generate_pressure(t, h))

# %%
data = wg.generate_weather(-17, 30, save=True, verbose=True, noise=True, deviation=0.5, outliers=0.15, nans=0.05)

# %%
data.head(10)
# Out:
#              datetime  temperature   lighting   humidity  pressure
# 0 2049-01-01 00:00:00       -18.00      -1.00       0.70    785.50
# 1 2049-01-01 00:30:00       -17.99      -1.00       0.82    791.48
# 2 2049-01-01 01:00:00       -17.96      -1.00  710000.00    785.93
# 3 2049-01-01 01:30:00       -17.92      -1.00       0.81    790.87
# 4 2049-01-01 02:00:00 -17860000.00 -990000.00  730000.00    786.77
# 5 2049-01-01 02:30:00 -17780000.00      -0.98       0.69    784.64
# 6 2049-01-01 03:00:00 -17700000.00        NaN       0.73    786.51
# 7 2049-01-01 03:30:00 -17590000.00      -0.92       0.76    787.83
# 8 2049-01-01 04:00:00       -17.48      -0.87       0.76    787.65
# 9 2049-01-01 04:30:00       -17.36      -0.79       0.73    785.96

# %%
print(data.temperature.values)
# Out:
# [-18.   -17.99 -17.96 ...    nan    nan    nan]

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,9))
ax1.plot(data.temperature.values)
ax2.plot(data.lighting.values)
ax3.plot(data.humidity.values)
ax4.plot(data.pressure.values)
plt.show()
